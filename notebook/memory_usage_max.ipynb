# %% [markdown]
# ## plot numerical data

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
current_dir = os.getcwd()  # 現在の作業ディレクトリを取得
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
import src.read as read
import src.utils as util

# %%
file_names = []
directory = "memory_usage/"
pattern = "maxmemory*.dat"

result = read.get_filenames_list_exp(directory, pattern)
file_names = result[0]
n_files = result[1]

print(file_names)
# Out:
# ['maxmemory1.dat', 'maxmemory2.dat', 'maxmemory3.dat', 'maxmemory4.dat']

# %%
array = read.read_files(directory, file_names)
print(type(array))
print(f"2次元配列の形状: {array.shape}")
# Out:
# <class 'numpy.ndarray'>
# 2次元配列の形状: (4, 7)

# %%
mean_HROM = []
n_means = array.shape[0]
n_data = array.shape[1]
tr = range(30, n_data)
mean_HROM = util.get_mean(array, n_means, target_dim=0, custom_flag=True, target_range=tr)

print(mean_HROM)
# Out:
# []

# %%
array = array.T
fig_3, ax_3 = plt.subplots()
data_names = ['propsed method online','existing method online','propsed method offline','existing method offline']

for i in range(1,(n_files+1),1):
    incr = 2**(i-1)
    data_names.append(f'err{incr}')

for i in range(0, n_files, 1):
    ax_3.plot(array[:,i], marker='x', label=data_names[i])

ax_3.set_xlabel('number of MPI processes')
ax_3.set_ylabel('max memory usage(kB)')
ax_3.legend(data_names)
ax_3.grid()
# ax_3.set_ylim(0.0, 0.001)
# ax_3.ticklabel_format(axis='y', style='sci', scilimits=(0,0), useMathText=True)

plt.show()

# %%
# array の形状は [7, 4] と仮定

fig_3, ax_3 = plt.subplots()
data_names = ['proposed method online', 'existing method online', 'proposed method offline', 'existing method offline']

# 横軸の値を設定
x_ticks = [1, 2, 4, 8, 16, 32, 64]

# プロット
for i in range(0, array.shape[1], 1):
    ax_3.plot(x_ticks, array[:, i], marker='x', label=data_names[i])

ax_3.set_xlabel('number of MPI processes')
ax_3.set_ylabel('max memory usage(kB)')
ax_3.legend()
ax_3.grid()

plt.show()

# %%
fig, ax = plt.subplots()
x = np.zeros(n_files)
for i in range(0,n_files,1):
    x[i] = 2**i

ax.plot(x, mean_HROM, marker='o')
ax.set_xlabel('number of subdomains')
ax.set_ylabel('error')
ax.grid()
ax_3.ticklabel_format(axis='y', style='sci', scilimits=(0,0), useMathText=True)
# ax.set_xscale('log')
# ax.set_xticks(mean_HROM)
# ax.set_xticklabels([2**i for i in range(0,len(mean_HROM))])
# ax.set_title('disp error')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 6
#       3 for i in range(0,n_files,1):
#       4     x[i] = 2**i
# ----> 6 ax.plot(x, mean_HROM, marker='o')
#       7 ax.set_xlabel('number of subdomains')
#       8 ax.set_ylabel('error')
#
# File ~/program/my_study/numerical_data/DataProcessing/venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/program/my_study/numerical_data/DataProcessing/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/program/my_study/numerical_data/DataProcessing/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (0,)
